# %% [markdown]
# # Conhecendo a request

# %% [markdown]
# ## Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ## Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"42367983591","type":"PushEvent","actor":{"id":39457393,"login":"kar525","display_login":"kar525","gravatar_id":"","url":"https://api.github.com/users/kar525","avatar_url":"https://avatars.githubusercontent.com/u/39457393?"},"repo":{"id":864801256,"name":"kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization","url":"https://api.github.com/repos/kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization"},"payload":{"repository_id":864801256,"push_id":20464608393,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"b630428d4af6632c2f5a2c687a64371270f7e68a","before":"7de7e0ad0e749cc570c620c9a082283a1e3100bd","commits":[{"sha":"b630428d4af6632c2f5a2c687a64371270f7e68a","author":{"email":"39457393+kar525@users.noreply.github.com","name":"kar525"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization/commits/b630428d4af6632c2f5a2c687a64371270f7e68a"}]},"public":true,"created_at":"2024-09-29T09:25:38Z"},{"id":"42367983589","type":"IssueCommentEvent","actor":{"id":74373520,"login":"Issues-translate-bot","display_login":"Issues-translate-bot","gravatar_id":"","url":"https://api.github.com/users/Issues-translate-bot","avatar_url":"https://avatars.githubusercontent.com/u/74373520?"},"repo":{"id":612344730,"name":"ChatGPTNextWeb/ChatGPT-Next-Web","url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561","repository_url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web","labels_url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/labels{/name}","comments_url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/comments","events_url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/events","html_url":"https://github.com/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561","id":2554672828,"node_id":"I_kwDOJH-jms6YRTa8","number":5561,"title":"[Feature Request] 后续有出apk的计划吗","user":{"login":"BuringFlames","id":40315058,"node_id":"MDQ6VXNlcjQwMzE1MDU4","avatar_url":"https://avatars.githubusercontent.com/u/40315058?v=4","gravatar_id":"","url":"https://api.github.com/users/BuringFlames","html_url":"https://github.com/BuringFlames","followers_url":"https://api.github.com/users/BuringFlames/followers","following_url":"https://api.github.com/users/BuringFlames/following{/other_user}","gists_url":"https://api.github.com/users/BuringFlames/gists{/gist_id}","starred_url":"https://api.github.com/users/BuringFlames/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BuringFlames/subscriptions","organizations_url":"https://api.github.com/users/BuringFlames/orgs","repos_url":"https://api.github.com/users/BuringFlames/repos","events_url":"https://api.github.com/users/BuringFlames/events{/privacy}","received_events_url":"https://api.github.com/users/BuringFlames/received_events","type":"User","site_admin":false},"labels":[{"id":5250811107,"node_id":"LA_kwDOJH-jms8AAAABOPkE4w","url":"https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/labels/enhancement","name":"enhancement","color":"a2eeef","default":true,"description":"New feature or request"}],"state":"closed","locked":false,"assignee":{"login":"Leizhenpeng","id":50035229,"node_id":"MDQ6VXNlcjUwMDM1MjI5","avatar_url":"https://avatars.githubusercontent.com/u/50035229?v=4","gravatar_id":"","url":"https://api.github.com/users/Leizhenpeng","html_url":"https://github.com/Leizhenpeng","followers_url":"https://api.github.com/users/Leizhenpeng/followers","following_url":"https://api.github.com/users/Leizhenpeng/following{/other_user}","gists_url":"https://api.github.com/users/Leizhenpeng/gists{/gist_id}","starred_url":"https://api.github.com/users/Leizhenpeng/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Leizhenpeng/subscriptions"," ...

# %%
r.json()
# Out:
# [{'id': '42367983591',
#   'type': 'PushEvent',
#   'actor': {'id': 39457393,
#    'login': 'kar525',
#    'display_login': 'kar525',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kar525',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39457393?'},
#   'repo': {'id': 864801256,
#    'name': 'kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization',
#    'url': 'https://api.github.com/repos/kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization'},
#   'payload': {'repository_id': 864801256,
#    'push_id': 20464608393,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b630428d4af6632c2f5a2c687a64371270f7e68a',
#    'before': '7de7e0ad0e749cc570c620c9a082283a1e3100bd',
#    'commits': [{'sha': 'b630428d4af6632c2f5a2c687a64371270f7e68a',
#      'author': {'email': '39457393+kar525@users.noreply.github.com',
#       'name': 'kar525'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kar525/Thailand-s_Budget_Explanatory_Analysis_and_Visualization/commits/b630428d4af6632c2f5a2c687a64371270f7e68a'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983589',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 74373520,
#    'login': 'Issues-translate-bot',
#    'display_login': 'Issues-translate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Issues-translate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74373520?'},
#   'repo': {'id': 612344730,
#    'name': 'ChatGPTNextWeb/ChatGPT-Next-Web',
#    'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561',
#     'repository_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web',
#     'labels_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/comments',
#     'events_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/events',
#     'html_url': 'https://github.com/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561',
#     'id': 2554672828,
#     'node_id': 'I_kwDOJH-jms6YRTa8',
#     'number': 5561,
#     'title': '[Feature Request] 后续有出apk的计划吗',
#     'user': {'login': 'BuringFlames',
#      'id': 40315058,
#      'node_id': 'MDQ6VXNlcjQwMzE1MDU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/40315058?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/BuringFlames',
#      'html_url': 'https://github.com/BuringFlames',
#      'followers_url': 'https://api.github.com/users/BuringFlames/followers',
#      'following_url': 'https://api.github.com/users/BuringFlames/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/BuringFlames/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/BuringFlames/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/BuringFlames/subscriptions',
#      'organizations_url': 'https://api.github.com/users/BuringFlames/orgs',
#      'repos_url': 'https://api.github.com/users/BuringFlames/repos',
#      'events_url': 'https://api.github.com/users/BuringFlames/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/BuringFlames/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 5250811107,
#       'node_id': 'LA_kwDOJH-jms8AAAABOPkE4w',
#       'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'a2eeef',
#       'default': True,
#       'description': 'New feature or request'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'Leizhenpeng',
#      'id': 50035229,
#      'node_id': 'MDQ6VXNlcjUwMDM1MjI5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/50035229?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Leizhenpeng',
#      'html_url': 'https://github.com/Leizhenpeng',
#      'followers_url': 'https://api.github.com/users/Leizhenpeng/followers',
#      'following_url': 'https://api.github.com/users/Leizhenpeng/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Leizhenpeng/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Leizhenpeng/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Leizhenpeng/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Leizhenpeng/orgs',
#      'repos_url': 'https://api.github.com/users/Leizhenpeng/repos',
#      'events_url': 'https://api.github.com/users/Leizhenpeng/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Leizhenpeng/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Leizhenpeng',
#       'id': 50035229,
#       'node_id': 'MDQ6VXNlcjUwMDM1MjI5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/50035229?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Leizhenpeng',
#       'html_url': 'https://github.com/Leizhenpeng',
#       'followers_url': 'https://api.github.com/users/Leizhenpeng/followers',
#       'following_url': 'https://api.github.com/users/Leizhenpeng/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Leizhenpeng/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Leizhenpeng/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Leizhenpeng/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Leizhenpeng/orgs',
#       'repos_url': 'https://api.github.com/users/Leizhenpeng/repos',
#       'events_url': 'https://api.github.com/users/Leizhenpeng/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Leizhenpeng/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2024-09-29T03:00:39Z',
#     'updated_at': '2024-09-29T09:25:38Z',
#     'closed_at': '2024-09-29T09:25:24Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '### 🥰 需求描述\n\n网页版的部署用起来不是很方便，想问下后续有没有包一个apk出来的计划\n\n### 🧐 解决方案\n\napk应用，安装后，初始化配置即用\n\n### 📝 补充信息\n\n_No response_',
#     'reactions': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'},
#    'comment': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/comments/2381280860',
#     'html_url': 'https://github.com/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561#issuecomment-2381280860',
#     'issue_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/5561',
#     'id': 2381280860,
#     'node_id': 'IC_kwDOJH-jms6N73Zc',
#     'user': {'login': 'Issues-translate-bot',
#      'id': 74373520,
#      'node_id': 'MDQ6VXNlcjc0MzczNTIw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/74373520?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Issues-translate-bot',
#      'html_url': 'https://github.com/Issues-translate-bot',
#      'followers_url': 'https://api.github.com/users/Issues-translate-bot/followers',
#      'following_url': 'https://api.github.com/users/Issues-translate-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Issues-translate-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Issues-translate-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Issues-translate-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Issues-translate-bot/orgs',
#      'repos_url': 'https://api.github.com/users/Issues-translate-bot/repos',
#      'events_url': 'https://api.github.com/users/Issues-translate-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Issues-translate-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-09-29T09:25:37Z',
#     'updated_at': '2024-09-29T09:25:37Z',
#     'author_association': 'NONE',
#     'body': " \n> Bot detected the issue body's language is not English, translate it automatically.         \n----    \nThe mac version can be used directly in release\r\n\r\nhttps://github.com/ChatGPTNextWeb/ChatGPT-Next-Web/releases/tag/v2.15.3  \n      ",
#     'reactions': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/comments/2381280860/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 153288546,
#    'login': 'ChatGPTNextWeb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ChatGPTNextWeb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153288546?'}},
#  {'id': '42367983583',
#   'type': 'PushEvent',
#   'actor': {'id': 37102945,
#    'login': 'AnriEU',
#    'display_login': 'AnriEU',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AnriEU',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37102945?'},
#   'repo': {'id': 569569539,
#    'name': 'AnriEU/tg',
#    'url': 'https://api.github.com/repos/AnriEU/tg'},
#   'payload': {'repository_id': 569569539,
#    'push_id': 20464608384,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3d9eac6de29e5349e8a10df0ca5b948d87f3b5e8',
#    'before': '64cbac88ab8d6d8c09c5eccaf179c78c3c19d3eb',
#    'commits': [{'sha': '3d9eac6de29e5349e8a10df0ca5b948d87f3b5e8',
#      'author': {'email': 'tvwk2013@gmail.com', 'name': 'AnriEU'},
#      'message': 'Upload file commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AnriEU/tg/commits/3d9eac6de29e5349e8a10df0ca5b948d87f3b5e8'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983580',
#   'type': 'PushEvent',
#   'actor': {'id': 115139640,
#    'login': 'freecall2019',
#    'display_login': 'freecall2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freecall2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115139640?'},
#   'repo': {'id': 806841319,
#    'name': 'freecall2019/day',
#    'url': 'https://api.github.com/repos/freecall2019/day'},
#   'payload': {'repository_id': 806841319,
#    'push_id': 20464608383,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aaf6d8dc448d65cfb37c532f9e8d1e3ba87f6df5',
#    'before': '072c65393eb2bf6688d63a9135432c9ec219520d',
#    'commits': [{'sha': 'aaf6d8dc448d65cfb37c532f9e8d1e3ba87f6df5',
#      'author': {'email': '115139640+freecall2019@users.noreply.github.com',
#       'name': 'freecall'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freecall2019/day/commits/aaf6d8dc448d65cfb37c532f9e8d1e3ba87f6df5'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983576',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 131264106,
#    'login': 'dmdeh',
#    'display_login': 'dmdeh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmdeh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131264106?'},
#   'repo': {'id': 852085244,
#    'name': 'Masidao/sip-of-travel',
#    'url': 'https://api.github.com/repos/Masidao/sip-of-travel'},
#   'payload': {'action': 'closed',
#    'number': 11,
#    'pull_request': {'url': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11',
#     'id': 2095196096,
#     'node_id': 'PR_kwDOMsnJ_M584ifA',
#     'html_url': 'https://github.com/Masidao/sip-of-travel/pull/11',
#     'diff_url': 'https://github.com/Masidao/sip-of-travel/pull/11.diff',
#     'patch_url': 'https://github.com/Masidao/sip-of-travel/pull/11.patch',
#     'issue_url': 'https://api.github.com/repos/Masidao/sip-of-travel/issues/11',
#     'number': 11,
#     'state': 'closed',
#     'locked': False,
#     'title': '[marron] #4 여행 일정 선택 페이지 구현',
#     'user': {'login': 'dmdeh',
#      'id': 131264106,
#      'node_id': 'U_kgDOB9Luag',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/131264106?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmdeh',
#      'html_url': 'https://github.com/dmdeh',
#      'followers_url': 'https://api.github.com/users/dmdeh/followers',
#      'following_url': 'https://api.github.com/users/dmdeh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmdeh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmdeh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmdeh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmdeh/orgs',
#      'repos_url': 'https://api.github.com/users/dmdeh/repos',
#      'events_url': 'https://api.github.com/users/dmdeh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmdeh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## 🔢 관련 이슈\r\n\r\n#4 \r\n\r\n## 🔧 변경 내용\r\n\r\n일정 선택 페이지 및 달력 컴포넌트 구현 \r\n\r\n## 🖥️ 스크린샷 (선택사항)\r\n<img width="50%" alt="스크린샷 2024-09-29 오후 6 18 34" src="https://github.com/user-attachments/assets/be2fc613-80b5-4d36-952a-41916019f19e"><img width="50%" alt="스크린샷 2024-09-29 오후 6 20 10" src="https://github.com/user-attachments/assets/d50ce9e0-fc2f-4889-8708-f5d423f6669d">\r\n\r\n- 하루만 선택도 가능\r\n- 두 날짜 선택 후 다른 날짜 클릭하면 다시 선택되는 형태\r\n\r\n## 🔒 이슈 닫기\r\n',
#     'created_at': '2024-09-27T07:26:50Z',
#     'updated_at': '2024-09-29T09:25:37Z',
#     'closed_at': '2024-09-29T09:25:37Z',
#     'merged_at': '2024-09-29T09:25:37Z',
#     'merge_commit_sha': '374d9c06fe6f9baeb8d5be4cfee7c771bcaea61f',
#     'assignee': {'login': 'dmdeh',
#      'id': 131264106,
#      'node_id': 'U_kgDOB9Luag',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/131264106?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmdeh',
#      'html_url': 'https://github.com/dmdeh',
#      'followers_url': 'https://api.github.com/users/dmdeh/followers',
#      'following_url': 'https://api.github.com/users/dmdeh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmdeh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmdeh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmdeh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmdeh/orgs',
#      'repos_url': 'https://api.github.com/users/dmdeh/repos',
#      'events_url': 'https://api.github.com/users/dmdeh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmdeh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'dmdeh',
#       'id': 131264106,
#       'node_id': 'U_kgDOB9Luag',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/131264106?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dmdeh',
#       'html_url': 'https://github.com/dmdeh',
#       'followers_url': 'https://api.github.com/users/dmdeh/followers',
#       'following_url': 'https://api.github.com/users/dmdeh/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dmdeh/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dmdeh/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dmdeh/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dmdeh/orgs',
#       'repos_url': 'https://api.github.com/users/dmdeh/repos',
#       'events_url': 'https://api.github.com/users/dmdeh/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dmdeh/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11/commits',
#     'review_comments_url': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11/comments',
#     'review_comment_url': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Masidao/sip-of-travel/issues/11/comments',
#     'statuses_url': 'https://api.github.com/repos/Masidao/sip-of-travel/statuses/c98aa0d2eba2d984a2a25d2ee10f9da2d0478a68',
#     'head': {'label': 'Masidao:feat/#4',
#      'ref': 'feat/#4',
#      'sha': 'c98aa0d2eba2d984a2a25d2ee10f9da2d0478a68',
#      'user': {'login': 'Masidao',
#       'id': 180366265,
#       'node_id': 'O_kgDOCsAruQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/180366265?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Masidao',
#       'html_url': 'https://github.com/Masidao',
#       'followers_url': 'https://api.github.com/users/Masidao/followers',
#       'following_url': 'https://api.github.com/users/Masidao/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Masidao/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Masidao/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Masidao/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Masidao/orgs',
#       'repos_url': 'https://api.github.com/users/Masidao/repos',
#       'events_url': 'https://api.github.com/users/Masidao/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Masidao/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 852085244,
#       'node_id': 'R_kgDOMsnJ_A',
#       'name': 'sip-of-travel',
#       'full_name': 'Masidao/sip-of-travel',
#       'private': False}},
#     'base': {'label': 'Masidao:front',
#      'ref': 'front',
#      'sha': '18b24da51d5622c8ff710ce69fa116323d49f403',
#      'user': {'login': 'Masidao',
#       'id': 180366265,
#       'node_id': 'O_kgDOCsAruQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/180366265?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Masidao',
#       'html_url': 'https://github.com/Masidao',
#       'followers_url': 'https://api.github.com/users/Masidao/followers',
#       'following_url': 'https://api.github.com/users/Masidao/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Masidao/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Masidao/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Masidao/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Masidao/orgs',
#       'repos_url': 'https://api.github.com/users/Masidao/repos',
#       'events_url': 'https://api.github.com/users/Masidao/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Masidao/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 852085244,
#       'node_id': 'R_kgDOMsnJ_A',
#       'name': 'sip-of-travel',
#       'full_name': 'Masidao/sip-of-travel',
#       'private': False}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11'},
#      'html': {'href': 'https://github.com/Masidao/sip-of-travel/pull/11'},
#      'issue': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/issues/11'},
#      'comments': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/issues/11/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/pulls/11/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Masidao/sip-of-travel/statuses/c98aa0d2eba2d984a2a25d2ee10f9da2d0478a68'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'dmdeh',
#      'id': 131264106,
#      'node_id': 'U_kgDOB9Luag',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/131264106?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmdeh',
#      'html_url': 'https://github.com/dmdeh',
#      'followers_url': 'https://api.github.com/users/dmdeh/followers',
#      'following_url': 'https://api.github.com/users/dmdeh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmdeh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmdeh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmdeh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmdeh/orgs',
#      'repos_url': 'https://api.github.com/users/dmdeh/repos',
#      'events_url': 'https://api.github.com/users/dmdeh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmdeh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 5,
#     'maintainer_can_modify': False,
#     'commits': 7,
#     'additions': 352,
#     'deletions': 6,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 180366265,
#    'login': 'Masidao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Masidao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/180366265?'}},
#  {'id': '42367983574',
#   'type': 'WatchEvent',
#   'actor': {'id': 77221529,
#    'login': 'zacwallsie',
#    'display_login': 'zacwallsie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zacwallsie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77221529?'},
#   'repo': {'id': 8629417,
#    'name': 'mapbox/mapbox-gl-js',
#    'url': 'https://api.github.com/repos/mapbox/mapbox-gl-js'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 600935,
#    'login': 'mapbox',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mapbox',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/600935?'}},
#  {'id': '42367983571',
#   'type': 'CreateEvent',
#   'actor': {'id': 166611144,
#    'login': 'minder-smoke-tests-infra[bot]',
#    'display_login': 'minder-smoke-tests-infra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/minder-smoke-tests-infra[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166611144?'},
#   'repo': {'id': 864829999,
#    'name': 'minder-smoke-tests/smoke-test-go-29280',
#    'url': 'https://api.github.com/repos/minder-smoke-tests/smoke-test-go-29280'},
#   'payload': {'ref': 'commit-binary',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 166534298,
#    'login': 'minder-smoke-tests',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/minder-smoke-tests',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166534298?'}},
#  {'id': '42367983567',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 624860365,
#    'name': 'soenneker/soenneker.blob.download',
#    'url': 'https://api.github.com/repos/soenneker/soenneker.blob.download'},
#   'payload': {'repository_id': 624860365,
#    'push_id': 20464608377,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '88d52df4bcd3262699713ea2023929a5bf7de793',
#    'before': 'e16b6a22f435fe1988481134af1ace85e3f1b9f4',
#    'commits': [{'sha': '88d52df4bcd3262699713ea2023929a5bf7de793',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'Update dependency Soenneker.Blob.Client to 2.1.900 (#1922)\n\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/soenneker/soenneker.blob.download/commits/88d52df4bcd3262699713ea2023929a5bf7de793'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983562',
#   'type': 'PushEvent',
#   'actor': {'id': 173535095,
#    'login': 'frdpzk2',
#    'display_login': 'frdpzk2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frdpzk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173535095?'},
#   'repo': {'id': 818567109,
#    'name': 'frdpzk2/ppub',
#    'url': 'https://api.github.com/repos/frdpzk2/ppub'},
#   'payload': {'repository_id': 818567109,
#    'push_id': 20464608372,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '334d8b76fa1a2d62647a50a669fd6930ef0cd75a',
#    'before': 'af2b5fde2f098d5e2be08c7dfeb7cfec30f5daef',
#    'commits': [{'sha': '334d8b76fa1a2d62647a50a669fd6930ef0cd75a',
#      'author': {'email': 'frdpzk2@gmail.com', 'name': 'frdpzk2'},
#      'message': 'commited',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/frdpzk2/ppub/commits/334d8b76fa1a2d62647a50a669fd6930ef0cd75a'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983564',
#   'type': 'PushEvent',
#   'actor': {'id': 41928138,
#    'login': 'sebast759',
#    'display_login': 'sebast759',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebast759',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41928138?'},
#   'repo': {'id': 457470784,
#    'name': 'sebast759/sebast759.github.io',
#    'url': 'https://api.github.com/repos/sebast759/sebast759.github.io'},
#   'payload': {'repository_id': 457470784,
#    'push_id': 20464608373,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f6891835e6ea90142243af2a45790f87f27f0baa',
#    'before': 'd5ef28c173ca99abaf634be4ae9078cf9cd3b9f8',
#    'commits': [{'sha': 'f6891835e6ea90142243af2a45790f87f27f0baa',
#      'author': {'email': '41928138+sebast759@users.noreply.github.com',
#       'name': 'sebast759'},
#      'message': 'Commit_aplo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sebast759/sebast759.github.io/commits/f6891835e6ea90142243af2a45790f87f27f0baa'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983563',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 747815339,
#    'name': 'radiorabe/container-image-mariadb',
#    'url': 'https://api.github.com/repos/radiorabe/container-image-mariadb'},
#   'payload': {'action': 'opened',
#    'number': 54,
#    'pull_request': {'url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54',
#     'id': 2097522934,
#     'node_id': 'PR_kwDOLJLBq859Baj2',
#     'html_url': 'https://github.com/radiorabe/container-image-mariadb/pull/54',
#     'diff_url': 'https://github.com/radiorabe/container-image-mariadb/pull/54.diff',
#     'patch_url': 'https://github.com/radiorabe/container-image-mariadb/pull/54.patch',
#     'issue_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/issues/54',
#     'number': 54,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore: bump radiorabe/ubi9-minimal from 0.7.2 to 0.7.3 in the baseimages group',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps the baseimages group with 1 update: [radiorabe/ubi9-minimal](https://github.com/radiorabe/container-image-ubi9-minimal).\n\nUpdates `radiorabe/ubi9-minimal` from 0.7.2 to 0.7.3\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/radiorabe/container-image-ubi9-minimal/releases">radiorabe/ubi9-minimal\'s releases</a>.</em></p>\n<blockquote>\n<h2>v0.7.3</h2>\n<h2>0.7.3 (2024-09-29)</h2>\n<h4>Bug Fixes</h4>\n<ul>\n<li>bump almalinux/9-minimal from 9.4-20240723 to 9.4-20240923 in the baseimages group across 1 directory (<a href="https://redirect.github.com/radiorabe/container-image-ubi9-minimal/issues/101">#101</a>) (22235b6c)</li>\n</ul>\n<h4>Chores</h4>\n<ul>\n<li><strong>ci:</strong> bump radiorabe/actions from 0.22.0 to 0.22.1 (<a href="https://redirect.github.com/radiorabe/container-image-ubi9-minimal/issues/99">#99</a>) (4eb77b04)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/radiorabe/container-image-ubi9-minimal/commit/22235b6c0f4e26f3fb18ac4c3602d16d986b8cb5"><code>22235b6</code></a> fix: bump almalinux/9-minimal from 9.4-20240723 to 9.4-20240923 in the baseim...</li>\n<li><a href="https://github.com/radiorabe/container-image-ubi9-minimal/commit/4eb77b0417ce71f28dbda6a62c5a5cc63031bd42"><code>4eb77b0</code></a> chore(ci): bump radiorabe/actions from 0.22.0 to 0.22.1 (<a href="https://redirect.github.com/radiorabe/container-image-ubi9-minimal/issues/99">#99</a>)</li>\n<li>See full diff in <a href="https://github.com/radiorabe/container-image-ubi9-minimal/compare/v0.7.2...v0.7.3">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=radiorabe/ubi9-minimal&package-manager=docker&previous-version=0.7.2&new-version=0.7.3)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot show <dependency name> ignore conditions` will show all of the ignore conditions of the specified dependency\n- `@dependabot ignore <dependency name> major version` will close this group update PR and stop Dependabot creating any more for the specific dependency\'s major version (unless you unignore this specific dependency\'s major version or upgrade to it yourself)\n- `@dependabot ignore <dependency name> minor version` will close this group update PR and stop Dependabot creating any more for the specific dependency\'s minor version (unless you unignore this specific dependency\'s minor version or upgrade to it yourself)\n- `@dependabot ignore <dependency name>` will close this group update PR and stop Dependabot creating any more for the specific dependency (unless you unignore this specific dependency or upgrade to it yourself)\n- `@dependabot unignore <dependency name>` will remove all of the ignore conditions of the specified dependency\n- `@dependabot unign ...
#     'created_at': '2024-09-29T09:25:36Z',
#     'updated_at': '2024-09-29T09:25:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4adcde801dafc1fc6770935b69bd62d87d5ad82b',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 6471959654,
#       'node_id': 'LA_kwDOLJLBq88AAAABgcJEZg',
#       'url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 6471959666,
#       'node_id': 'LA_kwDOLJLBq88AAAABgcJEcg',
#       'url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/labels/docker',
#       'name': 'docker',
#       'color': '21ceff',
#       'default': False,
#       'description': 'Pull requests that update Docker code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54/commits',
#     'review_comments_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54/comments',
#     'review_comment_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/issues/54/comments',
#     'statuses_url': 'https://api.github.com/repos/radiorabe/container-image-mariadb/statuses/8f22ca175c5bf5fe617fe565aa57df7f09a1b2f9',
#     'head': {'label': 'radiorabe:dependabot/docker/baseimages-18da099505',
#      'ref': 'dependabot/docker/baseimages-18da099505',
#      'sha': '8f22ca175c5bf5fe617fe565aa57df7f09a1b2f9',
#      'user': {'login': 'radiorabe',
#       'id': 3940873,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5NDA4NzM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3940873?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/radiorabe',
#       'html_url': 'https://github.com/radiorabe',
#       'followers_url': 'https://api.github.com/users/radiorabe/followers',
#       'following_url': 'https://api.github.com/users/radiorabe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/radiorabe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/radiorabe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/radiorabe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/radiorabe/orgs',
#       'repos_url': 'https://api.github.com/users/radiorabe/repos',
#       'events_url': 'https://api.github.com/users/radiorabe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/radiorabe/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 747815339,
#       'node_id': 'R_kgDOLJLBqw',
#       'name': 'container-image-mariadb',
#       'full_name': 'radiorabe/container-image-mariadb',
#       'private': False}},
#     'base': {'label': 'radiorabe:main',
#      'ref': 'main',
#      'sha': 'c6b2bf9a490d78441010f28d8f8226f22d630fab',
#      'user': {'login': 'radiorabe',
#       'id': 3940873,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5NDA4NzM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3940873?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/radiorabe',
#       'html_url': 'https://github.com/radiorabe',
#       'followers_url': 'https://api.github.com/users/radiorabe/followers',
#       'following_url': 'https://api.github.com/users/radiorabe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/radiorabe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/radiorabe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/radiorabe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/radiorabe/orgs',
#       'repos_url': 'https://api.github.com/users/radiorabe/repos',
#       'events_url': 'https://api.github.com/users/radiorabe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/radiorabe/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 747815339,
#       'node_id': 'R_kgDOLJLBqw',
#       'name': 'container-image-mariadb',
#       'full_name': 'radiorabe/container-image-mariadb',
#       'private': False}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54'},
#      'html': {'href': 'https://github.com/radiorabe/container-image-mariadb/pull/54'},
#      'issue': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/issues/54'},
#      'comments': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/issues/54/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/pulls/54/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/radiorabe/container-image-mariadb/statuses/8f22ca175c5bf5fe617fe565aa57df7f09a1b2f9'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 3940873,
#    'login': 'radiorabe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/radiorabe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3940873?'}},
#  {'id': '42367983565',
#   'type': 'CreateEvent',
#   'actor': {'id': 166611144,
#    'login': 'minder-smoke-tests-infra[bot]',
#    'display_login': 'minder-smoke-tests-infra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/minder-smoke-tests-infra[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166611144?'},
#   'repo': {'id': 864829997,
#    'name': 'minder-smoke-tests/smoke-test-go-31721',
#    'url': 'https://api.github.com/repos/minder-smoke-tests/smoke-test-go-31721'},
#   'payload': {'ref': 'test-invis-chars-homoglyph',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z',
#   'org': {'id': 166534298,
#    'login': 'minder-smoke-tests',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/minder-smoke-tests',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166534298?'}},
#  {'id': '42367983557',
#   'type': 'PushEvent',
#   'actor': {'id': 13162758,
#    'login': 'tada5hi',
#    'display_login': 'tada5hi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tada5hi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13162758?'},
#   'repo': {'id': 826797836,
#    'name': 'tada5hi/validup',
#    'url': 'https://api.github.com/repos/tada5hi/validup'},
#   'payload': {'repository_id': 826797836,
#    'push_id': 20464608368,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e09c86ef0ff74f0fbf02cd5023baeab9f0fdf31c',
#    'before': '78b8dff11fed89fff608aa987cd2d5aa5facfba3',
#    'commits': [{'sha': 'e09c86ef0ff74f0fbf02cd5023baeab9f0fdf31c',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'build(deps-dev): bump @rollup/plugin-node-resolve from 15.2.3 to 15.3.0 (#113)\n\nBumps [@rollup/plugin-node-resolve](https://github.com/rollup/plugins/tree/HEAD/packages/node-resolve) from 15.2.3 to 15.3.0.\r\n- [Changelog](https://github.com/rollup/plugins/blob/master/packages/node-resolve/CHANGELOG.md)\r\n- [Commits](https://github.com/rollup/plugins/commits/node-resolve-v15.3.0/packages/node-resolve)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: "@rollup/plugin-node-resolve"\r\n  dependency-type: direct:development\r\n  update-type: version-update:semver-minor\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tada5hi/validup/commits/e09c86ef0ff74f0fbf02cd5023baeab9f0fdf31c'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983554',
#   'type': 'PushEvent',
#   'actor': {'id': 52345271,
#    'login': 'IngenieurSong',
#    'display_login': 'IngenieurSong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IngenieurSong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52345271?'},
#   'repo': {'id': 437611452,
#    'name': 'IngenieurSong/algorithm_study',
#    'url': 'https://api.github.com/repos/IngenieurSong/algorithm_study'},
#   'payload': {'repository_id': 437611452,
#    'push_id': 20464608369,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6cba52b793f078fa22ce7d2e904568f2a3ac4a11',
#    'before': 'ff46500ccfc4e7bea2bd17a24d3975ead1fa94fc',
#    'commits': [{'sha': '6cba52b793f078fa22ce7d2e904568f2a3ac4a11',
#      'author': {'email': '52345271+IngenieurSong@users.noreply.github.com',
#       'name': 'Suin Song'},
#      'message': 'Update 2606.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IngenieurSong/algorithm_study/commits/6cba52b793f078fa22ce7d2e904568f2a3ac4a11'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983538',
#   'type': 'PushEvent',
#   'actor': {'id': 36180394,
#    'login': 'makersy',
#    'display_login': 'makersy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/makersy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36180394?'},
#   'repo': {'id': 589875485,
#    'name': 'makersy/lc-editor',
#    'url': 'https://api.github.com/repos/makersy/lc-editor'},
#   'payload': {'repository_id': 589875485,
#    'push_id': 20464608355,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dfa7c0f288bd316fd718c26f263b181ec2023904',
#    'before': '894f3c1eaa7822ddfa30c7d33903b2c0538a050d',
#    'commits': [{'sha': 'dfa7c0f288bd316fd718c26f263b181ec2023904',
#      'author': {'email': 'haoliny123@gmail.com', 'name': 'makersy'},
#      'message': 'day: 24/09/29',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/makersy/lc-editor/commits/dfa7c0f288bd316fd718c26f263b181ec2023904'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983533',
#   'type': 'PushEvent',
#   'actor': {'id': 179228472,
#    'login': 'idaxp394',
#    'display_login': 'idaxp394',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idaxp394',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/179228472?'},
#   'repo': {'id': 864436100,
#    'name': 'idaxp394/auto2',
#    'url': 'https://api.github.com/repos/idaxp394/auto2'},
#   'payload': {'repository_id': 864436100,
#    'push_id': 20464608356,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'edcab24317aa9e1385b952dab16a66664d3ccad3',
#    'before': 'e0784b9efc035366528395bf0b3e5fb58223be87',
#    'commits': [{'sha': 'edcab24317aa9e1385b952dab16a66664d3ccad3',
#      'author': {'email': 'idaxp72@gmail.com', 'name': 'idaxp394'},
#      'message': 'Upload file via API',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/idaxp394/auto2/commits/edcab24317aa9e1385b952dab16a66664d3ccad3'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983536',
#   'type': 'PushEvent',
#   'actor': {'id': 161594956,
#    'login': 'ElilyaOctaviani23',
#    'display_login': 'ElilyaOctaviani23',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ElilyaOctaviani23',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/161594956?'},
#   'repo': {'id': 850361186,
#    'name': 'ElilyaOctaviani23/Visualisasi-Data-dan-Informasi',
#    'url': 'https://api.github.com/repos/ElilyaOctaviani23/Visualisasi-Data-dan-Informasi'},
#   'payload': {'repository_id': 850361186,
#    'push_id': 20464608348,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bd06672dc714ca5f437cbe9d56c104d04d69f9cd',
#    'before': 'dab4d8b95d30d980fa510c2e1df05de269660722',
#    'commits': [{'sha': 'bd06672dc714ca5f437cbe9d56c104d04d69f9cd',
#      'author': {'email': '161594956+ElilyaOctaviani23@users.noreply.github.com',
#       'name': 'ElilyaOctaviani23'},
#      'message': 'Update Pertemuan 2_122450009_Elilya Octaviani.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ElilyaOctaviani23/Visualisasi-Data-dan-Informasi/commits/bd06672dc714ca5f437cbe9d56c104d04d69f9cd'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983534',
#   'type': 'PushEvent',
#   'actor': {'id': 162043249,
#    'login': 'omnixtar',
#    'display_login': 'omnixtar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/omnixtar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/162043249?'},
#   'repo': {'id': 766574506,
#    'name': 'omnixtar/omnixtar.github.io',
#    'url': 'https://api.github.com/repos/omnixtar/omnixtar.github.io'},
#   'payload': {'repository_id': 766574506,
#    'push_id': 20464608352,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aad86b5ac0c817e61f72aab01edc98930cc8a258',
#    'before': 'a419aaac8f82844391eb762777eeaa6c4a2d0f37',
#    'commits': [{'sha': 'aad86b5ac0c817e61f72aab01edc98930cc8a258',
#      'author': {'email': '162043249+omnixtar@users.noreply.github.com',
#       'name': 'omnixtar'},
#      'message': 'responseText',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/omnixtar/omnixtar.github.io/commits/aad86b5ac0c817e61f72aab01edc98930cc8a258'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983535',
#   'type': 'PushEvent',
#   'actor': {'id': 144984315,
#    'login': 'taeyungithub',
#    'display_login': 'taeyungithub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/taeyungithub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/144984315?'},
#   'repo': {'id': 861139302,
#    'name': 'taeyungithub/Make_Blog',
#    'url': 'https://api.github.com/repos/taeyungithub/Make_Blog'},
#   'payload': {'repository_id': 861139302,
#    'push_id': 20464608350,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1125d646b816b11ceb571c60657a78f9e37c3ea9',
#    'before': 'b9a370d445fb8e82077de337a8906532b3575cb9',
#    'commits': [{'sha': '1125d646b816b11ceb571c60657a78f9e37c3ea9',
#      'author': {'email': 'rlaxodbs629@naver.com', 'name': 'taeyungithub'},
#      'message': 'JWT로 로그인, 로그아웃 구현',
#      'distinct': True,
# ...
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-09-29T09:25:38Z'},
#  {'id': '42367983516',
#   'type': 'PushEvent',
#   'actor': {'id': 126553325,
#    'login': 'jilaypandya',
#    'display_login': 'jilaypandya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jilaypandya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126553325?'},
#   'repo': {'id': 566196309,
#    'name': 'ZEISS/zephyr',
#    'url': 'https://api.github.com/repos/ZEISS/zephyr'},
#   'payload': {'repository_id': 566196309,
#    'push_id': 20464608341,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/introduce-trinamic-driver',
#    'head': 'c1c828a482b73c8d1f7ed9ed61a3c7c29da3e7c9',
#    'before': '5d3070ee7a67b6a357b2f2bb6de185feb86c7f7c',
#    'commits': [{'sha': 'c1c828a482b73c8d1f7ed9ed61a3c7c29da3e7c9',
#      'author': {'email': 'jilay.pandya@zeiss.com', 'name': 'Jilay Pandya'},
#      'message': 'drivers: stepper: adi: trinamic tmc5041\n\nThis commit introduces initial structure for trinamic drivers\n\nSigned-off-by: Jilay Pandya <jilay.pandya@zeiss.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZEISS/zephyr/commits/c1c828a482b73c8d1f7ed9ed61a3c7c29da3e7c9'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:37Z',
#   'org': {'id': 36280239,
#    'login': 'ZEISS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ZEISS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36280239?'}},
#  {'id': '42367983512',
#   'type': 'PushEvent',
#   'actor': {'id': 166895733,
#    'login': 'swa-runner-app[bot]',
#    'display_login': 'swa-runner-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'},
#   'repo': {'id': 864829943,
#    'name': 'static-web-apps-testing-org/swaeb2b2ddd82614c7caf51fb15ec193674',
#    'url': 'https://api.github.com/repos/static-web-apps-testing-org/swaeb2b2ddd82614c7caf51fb15ec193674'},
#   'payload': {'repository_id': 864829943,
#    'push_id': 20464608336,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9171327f430ae9b153a891b168dfc2a150c86b13',
#    'before': 'a85584b0060d5ff2f91a10d7406490cf43ada191',
#    'commits': [{'sha': '9171327f430ae9b153a891b168dfc2a150c86b13',
#      'author': {'email': '166895733+swa-runner-app[bot]@users.noreply.github.com',
#       'name': 'swa-runner-app[bot]'},
#      'message': 'Writing file Client/Layout/MainLayout.razor.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/static-web-apps-testing-org/swaeb2b2ddd82614c7caf51fb15ec193674/commits/9171327f430ae9b153a891b168dfc2a150c86b13'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:37Z',
#   'org': {'id': 96167003,
#    'login': 'static-web-apps-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/static-web-apps-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}},
#  {'id': '42367983511',
#   'type': 'PushEvent',
#   'actor': {'id': 81374123,
#    'login': 'angelprokopov',
#    'display_login': 'angelprokopov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/angelprokopov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81374123?'},
#   'repo': {'id': 851098404,
#    'name': 'angelprokopov/angular-fundamentals-template',
#    'url': 'https://api.github.com/repos/angelprokopov/angular-fundamentals-template'},
#   'payload': {'repository_id': 851098404,
#    'push_id': 20464608331,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1f970a455b261470ee7e6c96218fa29d9263f37a',
#    'before': '06b1b47a8033ab94e2a904cd549acf24d492d898',
#    'commits': [{'sha': '1f970a455b261470ee7e6c96218fa29d9263f37a',
#      'author': {'email': '81374123+angelprokopov@users.noreply.github.com',
#       'name': 'angelprokopov'},
#      'message': 'Initial commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/angelprokopov/angular-fundamentals-template/commits/1f970a455b261470ee7e6c96218fa29d9263f37a'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:37Z'},
#  {'id': '42367983510',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 630196872,
#    'name': 'conda-forge/flux-core-feedstock',
#    'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59',
#     'repository_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock',
#     'labels_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59/comments',
#     'events_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59/events',
#     'html_url': 'https://github.com/conda-forge/flux-core-feedstock/pull/59',
#     'id': 2554802818,
#     'node_id': 'PR_kwDOJZAKiM59BUef',
#     'number': 59,
#     'title': 'Rebuild for libhwloc 2.11.2',
#     'user': {'login': 'regro-cf-autotick-bot',
#      'id': 36490558,
#      'node_id': 'MDQ6VXNlcjM2NDkwNTU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/36490558?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/regro-cf-autotick-bot',
#      'html_url': 'https://github.com/regro-cf-autotick-bot',
#      'followers_url': 'https://api.github.com/users/regro-cf-autotick-bot/followers',
#      'following_url': 'https://api.github.com/users/regro-cf-autotick-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/regro-cf-autotick-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/regro-cf-autotick-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/regro-cf-autotick-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/regro-cf-autotick-bot/orgs',
#      'repos_url': 'https://api.github.com/users/regro-cf-autotick-bot/repos',
#      'events_url': 'https://api.github.com/users/regro-cf-autotick-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/regro-cf-autotick-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 5410255888,
#       'node_id': 'LA_kwDOJZAKiM8AAAABQnn0EA',
#       'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/labels/automerge',
#       'name': 'automerge',
#       'color': '0e8a16',
#       'default': False,
#       'description': 'Merge the PR when CI passes'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2024-09-29T08:16:18Z',
#     'updated_at': '2024-09-29T09:25:37Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/pulls/59',
#      'html_url': 'https://github.com/conda-forge/flux-core-feedstock/pull/59',
#      'diff_url': 'https://github.com/conda-forge/flux-core-feedstock/pull/59.diff',
#      'patch_url': 'https://github.com/conda-forge/flux-core-feedstock/pull/59.patch',
#      'merged_at': None},
#     'body': "This PR has been triggered in an effort to update [**libhwloc2112**](https://conda-forge.org/status/migration/?name=libhwloc2112).\n\nNotes and instructions for merging this PR:\n1. Please merge the PR only after the tests have passed. \n2. Feel free to push to the bot's branch to update this PR if needed. \n\n**Please note that if you close this PR we presume that the feedstock has been rebuilt, so if you are going to perform the rebuild yourself don't close this PR until the your rebuild has been merged.**\n\n<hr>\n\nIf this PR was opened in error or needs to be updated please add the `bot-rerun` label to this PR. The bot will close this PR and schedule another one. If you do not have permissions to add this label, you can use the phrase <code>@<space/>conda-forge-admin, please rerun bot</code> in a PR comment to have the `conda-forge-admin` add it for you.\n\n<sub>This PR was created by the [regro-cf-autotick-bot](https://github.com/regro/cf-scripts). The **regro-cf-autotick-bot** is a service to automatically track the dependency graph, migrate packages, and propose package version updates for conda-forge. Feel free to drop us a line if there are any [issues](https://github.com/regro/cf-scripts/issues)! This PR was generated by https://github.com/regro/cf-scripts/actions/runs/11090842242 - please use this URL for debugging.</sub>",
#     'reactions': {'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/comments/2381280856',
#     'html_url': 'https://github.com/conda-forge/flux-core-feedstock/pull/59#issuecomment-2381280856',
#     'issue_url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/59',
#     'id': 2381280856,
#     'node_id': 'IC_kwDOJZAKiM6N73ZY',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2024-09-29T09:25:36Z',
#     'updated_at': '2024-09-29T09:25:36Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Hi! This is the friendly conda-forge automerge bot!\n\nI considered the following status checks when analyzing this PR:\n - **linter**: passed\n - **azure**: failed\n\n\nThus the PR was not passing and not merged.',
#     'reactions': {'url': 'https://api.github.com/repos/conda-forge/flux-core-feedstock/issues/comments/2381280856/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 15368,
#      'client_id': 'Iv1.05c79e9ad1f6bdfa',
#      'slug': 'github-actions',
#      'node_id': 'MDM6QXBwMTUzNjg=',
#      'owner': {'login': 'github',
#       'id': 9919,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk5MTk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9919?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/github',
#       'html_url': 'https://github.com/github',
#       'followers_url': 'https://api.github.com/users/github/followers',
#       'following_url': 'https://api.github.com/users/github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/github/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/github/subscriptions',
#       'organizations_url': 'https://api.github.com/users/github/orgs',
#       'repos_url': 'https://api.github.com/users/github/repos',
#       'events_url': 'https://api.github.com/users/github/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/github/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'name': 'GitHub Actions',
#      'description': 'Automate your workflow from idea to production',
#      'external_url': 'https://help.github.com/en/actions',
#      'html_url': 'https://github.com/apps/github-actions',
#      'created_at': '2018-07-30T09:30:17Z',
#      'updated_at': '2024-04-10T20:33:16Z',
#      'permissions': {'actions': 'write',
#       'administration': 'read',
#       'attestations': 'write',
#       'checks': 'write',
#       'contents': 'write',
#       'deployments': 'write',
#       'discussions': 'write',
#       'issues': 'write',
#       'merge_queues': 'write',
#       'metadata': 'read',
#       'packages': 'write',
#       'pages': 'write',
#       'pull_requests': 'write',
#       'repository_hooks': 'write',
#       'repository_projects': 'write',
#       'security_events': 'write',
#       'statuses': 'write',
#       'vulnerability_alerts': 'read'},
#      'events': ['branch_protection_rule',
#       'check_run',
#       'check_suite',
#       'create',
#       'delete',
#       'deployment',
#       'deployment_status',
#       'discussion',
#       'discussion_comment',
#       'fork',
#       'gollum',
#       'issues',
#       'issue_comment',
#       'label',
#       'merge_group',
#       'milestone',
#       'page_build',
#       'project',
#       'project_card',
#       'project_column',
#       'public',
#       'pull_request',
#       'pull_request_review',
#       'pull_request_review_comment',
#       'push',
#       'registry_package',
#       'release',
#       'repository',
#       'repository_dispatch',
#       'status',
#       'watch',
#       'workflow_dispatch',
#       'workflow_run']}}},
#   'public': True,
#   'created_at': '2024-09-29T09:25:37Z',
#   'org': {'id': 11897326,
#    'login': 'conda-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/conda-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?'}},
#  {'id': '42367983503',
#   'type': 'PushEvent',
#   'actor': {'id': 25373558,
#    'login': 'dsonyy',
#    'display_login': 'dsonyy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dsonyy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25373558?'},
#   'repo': {'id': 864492348,
#    'name': 'spejsiaczki/hy_app',
#    'url': 'https://api.github.com/repos/spejsiaczki/hy_app'},
#   'payload': {'repository_id': 864492348,
#    'push_id': 20464608328,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f3cab5221d3f08ebf5c3cf47796b425f63ee5edb',
#    'before': '085abb61d2e042806289a8ae2043ddaa3a75b801',
#    'commits': [{'sha': 'f3cab5221d3f08ebf5c3cf47796b425f63ee5edb',
#      'author': {'email': 'dsonyyy@gmail.com', 'name': 'Szymon Bednorz'},
#      'message': 'add reqs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/spejsiaczki/hy_app/commits/f3cab5221d3f08ebf5c3cf47796b425f63ee5edb'}]},
#   'public': True,
#   'created_at': '2024-09-29T09:25:37Z',
#   'org': {'id': 183193103,
#    'login': 'spejsiaczki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/spejsiaczki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/183193103?'}}]

# %% [markdown]
# * Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Desafio

# %%
d = requests.get('https://api.github.com/users/DeniseYuki')
d
# Out:
# <Response [200]>

# %%
d.status_code
# Out:
# 200

# %%
d.url
# Out:
# 'https://api.github.com/users/DeniseYuki'

# %%
d.text
# Out:
# '{"login":"DeniseYuki","id":49623035,"node_id":"MDQ6VXNlcjQ5NjIzMDM1","avatar_url":"https://avatars.githubusercontent.com/u/49623035?v=4","gravatar_id":"","url":"https://api.github.com/users/DeniseYuki","html_url":"https://github.com/DeniseYuki","followers_url":"https://api.github.com/users/DeniseYuki/followers","following_url":"https://api.github.com/users/DeniseYuki/following{/other_user}","gists_url":"https://api.github.com/users/DeniseYuki/gists{/gist_id}","starred_url":"https://api.github.com/users/DeniseYuki/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/DeniseYuki/subscriptions","organizations_url":"https://api.github.com/users/DeniseYuki/orgs","repos_url":"https://api.github.com/users/DeniseYuki/repos","events_url":"https://api.github.com/users/DeniseYuki/events{/privacy}","received_events_url":"https://api.github.com/users/DeniseYuki/received_events","type":"User","site_admin":false,"name":"Denise Yuki","company":null,"blog":"","location":null,"email":null,"hireable":true,"bio":"Professora de matemática desde 2013.\\r\\nFormada em Engenharia de Computação pela Univesp. Apaixonada por ciência de dados e Machine Learning. ","twitter_username":null,"public_repos":44,"public_gists":1,"followers":80,"following":98,"created_at":"2019-04-14T21:22:10Z","updated_at":"2024-09-29T09:28:12Z"}'

# %%
d.json()
# Out:
# {'login': 'DeniseYuki',
#  'id': 49623035,
#  'node_id': 'MDQ6VXNlcjQ5NjIzMDM1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/49623035?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/DeniseYuki',
#  'html_url': 'https://github.com/DeniseYuki',
#  'followers_url': 'https://api.github.com/users/DeniseYuki/followers',
#  'following_url': 'https://api.github.com/users/DeniseYuki/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/DeniseYuki/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/DeniseYuki/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/DeniseYuki/subscriptions',
#  'organizations_url': 'https://api.github.com/users/DeniseYuki/orgs',
#  'repos_url': 'https://api.github.com/users/DeniseYuki/repos',
#  'events_url': 'https://api.github.com/users/DeniseYuki/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/DeniseYuki/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Denise Yuki',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': True,
#  'bio': 'Professora de matemática desde 2013.\r\nFormada em Engenharia de Computação pela Univesp. Apaixonada por ciência de dados e Machine Learning. ',
#  'twitter_username': None,
#  'public_repos': 44,
#  'public_gists': 1,
#  'followers': 80,
#  'following': 98,
#  'created_at': '2019-04-14T21:22:10Z',
#  'updated_at': '2024-09-29T09:28:12Z'}

# %% [markdown]
# * 1 - Nome

# %%
d.json()['name']
# Out:
# 'Denise Yuki'

# %% [markdown]
# * 2 - Nome de usuário

# %%
d.json()['login']
# Out:
# 'DeniseYuki'

# %% [markdown]
# * 3 - Número de repositórios públicos

# %%
d.json()['public_repos']
# Out:
# 44

# %% [markdown]
# * 4 - Data de criação da conta no GitHub

# %%
d.json()['created_at']
# Out:
# '2019-04-14T21:22:10Z'

# %% [markdown]
# * Nessa aula, você aprendeu a:
# Trabalhar no WSL;
# Configurar um ambiente virtual;
# Utilizar a biblioteca Requests do Python;
# Extrair dados de uma API REST;
# Realizar uma requisição GET;
# Identificar status codes;
# Manipular endpoints.

# %% [markdown]
# ## Extraindo dados
